# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
# %cd /content/drive/MyDrive/final_code_SA_NLP
# !ls

# %%
# !pip install torch transformers scikit-learn tqdm underthesea

# %%
# !python main_test.py

# %%
# !python main.py

# %%
import os
os.chdir("/content/drive/MyDrive/final_code_SA_NLP")
print("Thư mục hiện tại:", os.getcwd())

# %%
# !python /content/drive/MyDrive/final_code_SA_NLP/main_inference.py

# %% [markdown]
# GIAO DIỆN

# %%
# !python demo.py
